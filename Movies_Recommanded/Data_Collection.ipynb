# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew Ref.
# 0  Adam Robitel (director); Leigh Whannell (scree...  [2]
# 1  Lauren Wolkstein (director); Christopher Radcl...  [3]
# 2  Simon West (director); Duncan Falconer, Warren...  [4]
# 3  Warwick Thornton (director); David Tranter, St...  [5]
# 4  Jaume Collet-Serra (director); Byron Willinger...  [6]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres
# 0  Mystery Horror Thriller
# 1           Thriller Drama
# 2          Action Thriller
# 3    Drama History Western
# 4          Action Thriller

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name    actor_1_name  \
# 0  Mystery Horror Thriller        Adam Robitel       Lin Shaye
# 1           Thriller Drama    Lauren Wolkstein   Alex Pettyfer
# 2          Action Thriller          Simon West  Dominic Cooper
# 3    Drama History Western    Warwick Thornton     Bryan Brown
# 4          Action Thriller  Jaume Collet-Serra     Liam Neeson
#
#              actor_2_name    actor_3_name
# 0           Angus Sampson  Leigh Whannell
# ...

# %%
df_2018 = df_2018.rename(columns={'Title' : 'title'})
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','title']]
new_df18.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill             NaN
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                     genres                    title
# 0  Mystery Horror Thriller  Insidious: The Last Key
# 1           Thriller Drama         The Strange Ones
# 2          Action Thriller                 Stratton
# 3    Drama History Western            Sweet Country
# 4          Action Thriller             The Commuter

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'None')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'None')

# %%
new_df18['title'] = new_df18['title'].str.lower()

# %%
new_df18['combination'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df_2019 = df[['Title','Cast and crew','genres']]
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

df_2019 = df_2019.rename(columns={'Title' : 'title'})
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','title']]

new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'None')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'None')

new_df19['title'] = new_df19['title'].str.lower()
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
my_df = new_df18.append(new_df19,ignore_index=True)
# Out:
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
old_df = pd.read_csv('new_data.csv')
final_df = old_df.append(my_df,ignore_index=True)
final_df.isnull().sum()
final_df = final_df.dropna(how='any')
final_df.to_csv('final_data.csv',index=False)

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]
# source = urllib.request.urlopen(link).read()
# soup = bs.BeautifulSoup(source,'lxml')
# tables = soup.find_all('table',class_='wikitable sortable')
# len(tables)
# type(tables[0])
# df1 = pd.read_html(str(tables[0]))[0]
# df2 = pd.read_html(str(tables[1]))[0]
# df3 = pd.read_html(str(tables[2]))[0]
# df4 = pd.read_html(str(tables[3]))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"' .replace("'1\"\'",'"1"')
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df_2020 = df[['Title','Cast and crew']]
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '5492165c61b1a21c06eb3a3b578a6339'
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))

def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

df_2020 = df_2020.rename(columns={'Title' : 'title'})
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','title']]
new_df20['combination'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']
new_df20.isna().sum()
new_df20 = new_df20.dropna(how='any')
new_df20.isna().sum()
new_df20['title'] = new_df20['title'].str.lower()
new_df20.head()
# Out:
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\SHIVAM CHOUDHARY\anaconda3\lib\site-packages\ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
old_df = pd.read_csv('final_data.csv')
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df.to_csv('main_data.csv',index=False)
